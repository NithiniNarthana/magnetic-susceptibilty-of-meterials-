# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\040.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference (g)')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\050.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\060.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\070.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\080.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\090.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\100.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Upload the Excel file
file_path = r'C:\Users\narth\Downloads\110.xlsx'  # Raw string prevents escape sequences
 # Replace with your Excel file path
data = pd.read_excel(file_path)

# Extract columns
current = data['current']
mean = data['mean']
std = data['std']

# Plot with error bars
plt.errorbar(current, mean, yerr=std, fmt='o', label='Data', capsize=5, color='blue')
plt.xlabel('Current (mA)')
plt.ylabel('Mean mass difference')

plt.legend()
plt.grid(True)
plt.show()

# Gradient and error calculation
# Perform linear regression (least squares fit)
coeffs, cov_matrix = np.polyfit(current, mean, deg=1, cov=True)
gradient, intercept = coeffs
gradient_error = np.sqrt(cov_matrix[0, 0])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Data
gradient_array = [0.00081543,0.00103329,0.00119941,0.00139424, 0.00161444, 0.00163776, 0.00171223, 0.00189340]
error_gradient = [0.00001162,0.00002340, 0.00002984, 0.00001922,0.00005652,0.00007170,0.00002589,0.00007070]
c = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1]



0.42101707239470987
0.005998724606367318
# Convert to NumPy arrays
gradient_array = np.array(gradient_array)
error_gradient = np.array(error_gradient)
c = np.array(c)

# Perform calculations
B_field = gradient_array * 9.81 / (1.9 * 10**(-2))
error_of_B = error_gradient * 9.81 / (1.9 * 10**(-2))

# Plot graph with error bars
plt.errorbar(c, B_field, yerr=error_of_B, fmt='o', label='Data', capsize=5)
plt.xlabel('current of the electromagnet (A)')
plt.ylabel('B Field (T)')
plt.title('B Field vs c with Error Bars')
plt.grid(True)

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(c, B_field)

# Plot regression line
regression_line = slope * c + intercept
plt.plot(c, regression_line, 'r-', label=f'Fit: B = {slope:.4f}c + {intercept:.4f}')
plt.legend()

# Show plot
plt.show()

# Print regression results
print(f"Linear Regression Equation: B = {slope:.4f}c + {intercept:.4f}")
print(f"R-squared: {r_value**2:.4f}")
print(f"Standard Error of Slope: {std_err:.4f}")
# Out:
# Linear Regression Equation: B = 0.7668c + 0.1542
# R-squared: 0.9664
# Standard Error of Slope: 0.0584

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#for NiCl2 
# Upload the Excel file
file_path = r"C:\Users\narth\Downloads\NiCl2.xlsx"  # Raw string prevents escape sequences
data = pd.read_excel(file_path)

# Extract columns
current = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2]
mean = data['mean']
std = data['std']

current = np.array(current)  # Convert current to a NumPy array
B = 0.7668 * current + 0.1542
square_B = B**2

# Plot graph with error bars
plt.errorbar(square_B, mean * 10**(-3), yerr=std * 10**(-3), fmt='o', label='Data', capsize=5)
plt.xlabel('square of B_field(T)')
plt.ylabel('mass (Kg)')
plt.title('B Field vs c with Error Bars')
plt.grid(True)

# Perform linear regression
mean_scaled = mean * 10**(-3)
slope, intercept = np.polyfit(square_B, mean_scaled, 1)

# Calculate the error in the slope (gradient)
N = len(square_B)
y_fit = slope * square_B + intercept
residuals = mean_scaled - y_fit
residual_std = np.sqrt(np.sum(residuals**2) / (N - 2))

delta_x = square_B - np.mean(square_B)
slope_error = residual_std / np.sqrt(np.sum(delta_x**2))

# Display the slope and its error
print(f"Gradient (slope): {slope:.10f}")
print(f"Error in gradient: {slope_error:.10f}")

# Plot the best-fit line
plt.plot(square_B, y_fit, label=f'Fit: y = {slope:.2e}x + {intercept:.2e}')
plt.legend()
plt.show()
# Calculate the Pearson correlation coefficient (r-value)
r_value = np.corrcoef(square_B, mean_scaled)[0, 1]

# Display the r-value
print(f"R-value (correlation coefficient): {r_value:.4f}")
# Out:
# Gradient (slope): 0.0000622442
# Error in gradient: 0.0000035872
# R-value (correlation coefficient): 0.9886

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
file_path = r"C:\Users\narth\Downloads\water.xlsx" # Adjust the file path as needed
data = pd.read_excel(file_path)

# Check column names
print("Columns in the dataset:", data.columns)

# Extract columns
current = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2]
mean = data['mean']  # Ensure this column exists
std_column = 'std'  # Replace with the actual column name if different
if std_column in data.columns:
    std = data[std_column]
else:
    raise KeyError(f"Column '{std_column}' not found in the dataset. Check the file.")

# Perform calculations
current = np.array(current)  # Convert to a NumPy array
B = 0.7668 * current + 0.1542
square_B = B**2

# Plot the data with error bars
plt.errorbar(square_B, mean * 10**(-3), yerr=std * 10**(-3), fmt='o', label='Data', capsize=5)
plt.xlabel('B_field (T^2)')
plt.ylabel('Mass (kg)')
plt.title('B Field vs Mass with Error Bars')
plt.grid(True)

# Perform linear regression
mean_scaled = mean * 10**(-3)
slope, intercept = np.polyfit(square_B, mean_scaled, 1)

# Calculate error in the slope (gradient)
N = len(square_B)
y_fit = slope * square_B + intercept
residuals = mean_scaled - y_fit
residual_std = np.sqrt(np.sum(residuals**2) / (N - 2))
delta_x = square_B - np.mean(square_B)
slope_error = residual_std / np.sqrt(np.sum(delta_x**2))

# Display results
print(f"Gradient (slope): {slope:.10f}")
print(f"Error in gradient: {slope_error:.10f}")

# Plot the best-fit line
plt.plot(square_B, y_fit, label=f'Fit: y = {slope:.2e}x + {intercept:.2e}')
plt.legend()
plt.show()

# Calculate the Pearson correlation coefficient (r-value)
r_value = np.corrcoef(square_B, mean_scaled)[0, 1]

# Display the r-value
print(f"R-value (correlation coefficient): {r_value:.4f}")
# Out:
# Columns in the dataset: Index(['current ', 'm1', 'm2', 'm3', 'mean', 'std', 'mean_glass',
#        'corrected_mass'],
#       dtype='object')
# Gradient (slope): -0.0000073831
# Error in gradient: 0.0000010707
# R-value (correlation coefficient): -0.9336
